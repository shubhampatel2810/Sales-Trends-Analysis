# %% [markdown]
# # This is simple EDA project of Retail Sales

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
doc =pd.read_csv('retail_sales_dataset.csv')

# %%
doc
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
doc.head(7)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 5               6  2023-04-25     CUST006  Female   45           Beauty
# 6               7  2023-03-13     CUST007    Male   46         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100
# 5         1              30            30
# 6         2              25            50

# %%
doc.head(5)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
doc
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
doc.index = doc.index + 1

# %%
doc
# Out:
#       Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 1                  1  2023-11-24     CUST001    Male   34           Beauty
# 2                  2  2023-02-27     CUST002  Female   26         Clothing
# 3                  3  2023-01-13     CUST003    Male   50      Electronics
# 4                  4  2023-05-21     CUST004    Male   37         Clothing
# 5                  5  2023-05-06     CUST005    Male   30           Beauty
# ...              ...         ...         ...     ...  ...              ...
# 996              996  2023-05-16     CUST996    Male   62         Clothing
# 997              997  2023-11-17     CUST997    Male   52           Beauty
# 998              998  2023-10-29     CUST998  Female   23           Beauty
# 999              999  2023-12-05     CUST999  Female   36      Electronics
# 1000            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#       Quantity  Price per Unit  Total Amount
# ...

# %%
doc.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
doc.max()
# Out:
# Transaction ID             1000
# Date                 2024-01-01
# Customer ID             CUST999
# Gender                     Male
# Age                          64
# Product Category    Electronics
# Quantity                      4
# Price per Unit              500
# Total Amount               2000
# dtype: object

# %%
doc.isnull()
# Out:
#       Transaction ID   Date  Customer ID  Gender    Age  Product Category  \
# 1              False  False        False   False  False             False
# 2              False  False        False   False  False             False
# 3              False  False        False   False  False             False
# 4              False  False        False   False  False             False
# 5              False  False        False   False  False             False
# ...              ...    ...          ...     ...    ...               ...
# 996            False  False        False   False  False             False
# 997            False  False        False   False  False             False
# 998            False  False        False   False  False             False
# 999            False  False        False   False  False             False
# 1000           False  False        False   False  False             False
#
#       Quantity  Price per Unit  Total Amount
# ...

# %%
doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 1 to 1000
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
doc.tail(5)
# Out:
#       Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 996              996  2023-05-16     CUST996    Male   62         Clothing
# 997              997  2023-11-17     CUST997    Male   52           Beauty
# 998              998  2023-10-29     CUST998  Female   23           Beauty
# 999              999  2023-12-05     CUST999  Female   36      Electronics
# 1000            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#       Quantity  Price per Unit  Total Amount
# 996          1              50            50
# 997          3              30            90
# 998          4              25           100
# 999          3              50           150
# 1000         4              30           120

# %%
doc.shape
# Out:
# (1000, 9)

# %%
doc.shape
# Out:
# (1000, 9)

# %%
doc.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
doc.groupby('Quantity')['Total Amount'].min()
# Out:
# Quantity
# 1     25
# 2     50
# 3     75
# 4    100
# Name: Total Amount, dtype: int64

# %%
doc['Age'].hist()
# Out:
# <Axes: >

# %%
doc['Quantity'].hist()
# Out:
# <Axes: >

# %%
doc.boxplot(column = 'Age')
# Out:
# <Axes: >

# %%
doc.boxplot(column="Total Amount")
# Out:
# <Axes: >

# %%
scatter_matrix(doc, figsize=(5, 5))
# Out:
# array([[<Axes: xlabel='Transaction ID', ylabel='Transaction ID'>,
#         <Axes: xlabel='Age', ylabel='Transaction ID'>,
#         <Axes: xlabel='Quantity', ylabel='Transaction ID'>,
#         <Axes: xlabel='Price per Unit', ylabel='Transaction ID'>,
#         <Axes: xlabel='Total Amount', ylabel='Transaction ID'>],
#        [<Axes: xlabel='Transaction ID', ylabel='Age'>,
#         <Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Quantity', ylabel='Age'>,
#         <Axes: xlabel='Price per Unit', ylabel='Age'>,
#         <Axes: xlabel='Total Amount', ylabel='Age'>],
#        [<Axes: xlabel='Transaction ID', ylabel='Quantity'>,
#         <Axes: xlabel='Age', ylabel='Quantity'>,
#         <Axes: xlabel='Quantity', ylabel='Quantity'>,
#         <Axes: xlabel='Price per Unit', ylabel='Quantity'>,
#         <Axes: xlabel='Total Amount', ylabel='Quantity'>],
#        [<Axes: xlabel='Transaction ID', ylabel='Price per Unit'>,
# ...

# %%
doc['Total Amount'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Total Amount'>

# %% [markdown]
# # Data Cleaning

# %%
doc.dropna()
# Out:
#       Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 1                  1  2023-11-24     CUST001    Male   34           Beauty
# 2                  2  2023-02-27     CUST002  Female   26         Clothing
# 3                  3  2023-01-13     CUST003    Male   50      Electronics
# 4                  4  2023-05-21     CUST004    Male   37         Clothing
# 5                  5  2023-05-06     CUST005    Male   30           Beauty
# ...              ...         ...         ...     ...  ...              ...
# 996              996  2023-05-16     CUST996    Male   62         Clothing
# 997              997  2023-11-17     CUST997    Male   52           Beauty
# 998              998  2023-10-29     CUST998  Female   23           Beauty
# 999              999  2023-12-05     CUST999  Female   36      Electronics
# 1000            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#       Quantity  Price per Unit  Total Amount
# ...

# %%
doc=doc.fillna('Age')

# %%
doc.drop_duplicates()
# Out:
#       Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 1                  1  2023-11-24     CUST001    Male   34           Beauty
# 2                  2  2023-02-27     CUST002  Female   26         Clothing
# 3                  3  2023-01-13     CUST003    Male   50      Electronics
# 4                  4  2023-05-21     CUST004    Male   37         Clothing
# 5                  5  2023-05-06     CUST005    Male   30           Beauty
# ...              ...         ...         ...     ...  ...              ...
# 996              996  2023-05-16     CUST996    Male   62         Clothing
# 997              997  2023-11-17     CUST997    Male   52           Beauty
# 998              998  2023-10-29     CUST998  Female   23           Beauty
# 999              999  2023-12-05     CUST999  Female   36      Electronics
# 1000            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#       Quantity  Price per Unit  Total Amount
# ...

# %%
doc.index = doc.index + 1

# %%
doc
# Out:
#       Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 1                  1  2023-11-24     CUST001    Male   34           Beauty
# 2                  2  2023-02-27     CUST002  Female   26         Clothing
# 3                  3  2023-01-13     CUST003    Male   50      Electronics
# 4                  4  2023-05-21     CUST004    Male   37         Clothing
# 5                  5  2023-05-06     CUST005    Male   30           Beauty
# ...              ...         ...         ...     ...  ...              ...
# 996              996  2023-05-16     CUST996    Male   62         Clothing
# 997              997  2023-11-17     CUST997    Male   52           Beauty
# 998              998  2023-10-29     CUST998  Female   23           Beauty
# 999              999  2023-12-05     CUST999  Female   36      Electronics
# 1000            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#       Quantity  Price per Unit  Total Amount
# ...

# %% [markdown]
# # Now we See Visualization

# %%
plt.figure(figsize=(10, 6))
sns.histplot(doc['Age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
doc.head(2)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 1               1  2023-11-24     CUST001    Male   34           Beauty
# 2               2  2023-02-27     CUST002  Female   26         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 1         3              50           150
# 2         2             500          1000

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Total Amount', data=doc)
plt.title('Scatter Plot of Age vs. Total Amount')
plt.xlabel('Age')
plt.ylabel('Toatl Amount')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.countplot(x='Product Category', data=doc)
plt.title('Count of Each Product Category')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.boxplot(x='Product Category', y='Age', data=doc)
plt.title('Box Plot of Value by Age')
plt.xlabel('Product Category')
plt.ylabel('Age')
plt.show()

# %%
plt.figure(figsize=(10, 3))
sns.violinplot(x='Age', y='Total Amount', data=doc)
plt.title('Vilin Plot chart for spend highest money age')
plt.xlabel('Age')
plt.ylabel('Toatl Amount')
plt.show()

# %%
plt.figure(figsize=(10, 3))
sns.countplot(x='Age', data=doc)
plt.title('Number of customer by age  ')
plt.xlabel('Age')
# plt.ylabel('Toatl Amount')
plt.show()

# %%
plt.figure(figsize=(8, 4))  # Set the figure size
sns.countplot(x='Date', data=doc, order=doc['Date'].value_counts().index[:10])  # Order by the top 10 dates
plt.title('Top 10 Dates with the Highest Sales')
plt.xlabel('Date')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
